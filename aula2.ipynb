# %% [markdown]
# # Pesquisa: Música na sala de aula
#
# ### Estilos musicais
# - rock
# - hip hop
# - mpb
# - reggae
# - funk
# - sertanejo
# - gospel
# - eletrônica

# %% [markdown]
# ### Objetivo: usar a inteligência artificial na sala de aula, gerando musicas nerds com ritmos que os alunos terão uma experiencia imersiva na aula.

# %% [markdown]
# Passo 1 - entrar no google forms

# %% [markdown]
# Passo 2 - gerar o cvs

# %% [markdown]
# Passo 3 - Importar o csv

# %%
import pandas as pd

# %%
import seaborn as sns

# %% [markdown]
# https://dontpad.com/pesquisamusical
#
# {#link da pesquisa#}
# https://forms.gle/RbSgu8jfDmFjxZ1m8
#
# {#link da planilha#}
# https://docs.google.com/spreadsheets/d/1RFcHdzoyqB6jat7o7bAA5XjvLql5j11FVfHk4FQtKVg/edit?usp=sharing
# {#tarefas#}
#
# - tarefa 1 - exportar a planilha como .csv
# - tarefa 2- importar o .csv no pandas
# - tarefa 3- remover a primeira coluna
# - tarefa 4- escolher um gráfico que possa mostrar para
# a professora e o orquestrador de IA quais os estilos
# tiveram um nota maior ou menor.
# - tarefa 5- faça um boxplot e um histograma
# identique a mediana , outliers e conte uma história.

# %% [markdown]
# ### Tarefa 1 - exportar a planilha como .csv

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1RFcHdzoyqB6jat7o7bAA5XjvLql5j11FVfHk4FQtKVg/edit?usp=sharing

# %% [markdown]
# ### Tarefa 2- importar o .csv no pandas

# %%
pesquisa_musical = pd.read_csv('datasets/pesquisa_musical.csv')
pesquisa_musical.head()
# Out:
#   Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0  21/08/2024 10:03:25                                  3
# 1  21/08/2024 10:04:39                                  5
# 2  21/08/2024 10:04:52                                  1
# 3  21/08/2024 10:04:53                                  1
# 4  21/08/2024 10:04:55                                  5
#
#    Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 0                                     1                                 1
# 1                                     3                                 5
# 2                                     5                                 1
# 3                                     5                                 4
# 4                                     4                                 3
#
#    Avalie os estilos musicais [reggae]  Avalie os estilos musicais [funk]  \
# 0                                    1                                  1
# 1                                    2                                  1
# 2                                    1                                  1
# 3                                    4                                  4
# 4                                    4                                  1
#
#    Avalie os estilos musicais [sertanejo]  \
# 0                                       1
# 1                                       3
# 2                                       1
# 3                                       1
# 4                                       1
#
#    Avalie os estilos musicais [gospel]  \
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    2
#
#    Avalie os estilos musicais [eletrônica] Qual professor  \
# 0                                        3            NaN
# 1                                        5            NaN
# 2                                        5            NaN
# 3                                        5            NaN
# 4                                        5            NaN
#
#   Qual sua faixa etária
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
type(pesquisa_musical)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Tarefa 3- remover a primeira coluna

# %%
df_music = pesquisa_musical.drop(columns=['Carimbo de data/hora','Qual professor','Qual sua faixa etária'])
df_music
# Out:
#     Avalie os estilos musicais [rock]  Avalie os estilos musicais [hip hop]  \
# 0                                   3                                     1
# 1                                   5                                     3
# 2                                   1                                     5
# 3                                   1                                     5
# 4                                   5                                     4
# ..                                ...                                   ...
# 90                                  3                                     4
# 91                                  1                                     1
# 92                                  1                                     1
# 93                                  5                                     2
# 94                                  5                                     5
#
#     Avalie os estilos musicais [mpb]  Avalie os estilos musicais [reggae]  \
# 0                                  1                                    1
# 1                                  5                                    2
# 2                                  1                                    1
# 3                                  4                                    4
# 4                                  3                                    4
# ..                               ...                                  ...
# 90                                 2                                    2
# 91                                 1                                    1
# 92                                 5                                    1
# 93                                 4                                    2
# 94                                 5                                    5
#
#     Avalie os estilos musicais [funk]  Avalie os estilos musicais [sertanejo]  \
# 0                                   1                                       1
# 1                                   1                                       3
# 2                                   1                                       1
# 3                                   4                                       1
# 4                                   1                                       1
# ..                                ...                                     ...
# 90                                  3                                       4
# 91                                  1                                       1
# 92                                  1                                       1
# 93                                  1                                       4
# 94                                  5                                       5
#
#     Avalie os estilos musicais [gospel]  \
# 0                                     1
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     2
# ..                                  ...
# 90                                    1
# 91                                    1
# 92                                    5
# 93                                    1
# 94                                    5
#
#     Avalie os estilos musicais [eletrônica]
# 0                                         3
# 1                                         5
# 2                                         5
# 3                                         5
# 4                                         5
# ..                                      ...
# 90                                        4
# 91                                        1
# 92                                        1
# 93                                        5
# 94                                        5
#
# [95 rows x 8 columns]

# %%
df_music.columns = ['rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletrônica']

# %%
df_music.head()
# Out:
#    rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletrônica
# 0     3       1    1       1     1          1       1           3
# 1     5       3    5       2     1          3       1           5
# 2     1       5    1       1     1          1       1           5
# 3     1       5    4       4     4          1       1           5
# 4     5       4    3       4     1          1       2           5

# %% [markdown]
# ### Tarefa 4- escolher um gráfico que possa mostrar para a professora e o orquestrador de IA quais os estilos tiveram um nota maior ou menor.

# %%
import matplotlib.pyplot as plt

# %%
# Configurações para melhorar visualização dos gráficos
plt.figure(figsize=(14, 10))

# %%
soma_pontuacoes = df_music.sum()
soma_pontuacoes
# Out:
# rock          310
# hiphop        293
# mpb           308
# reggae        245
# funk          231
# sertanejo     274
# gospel        252
# eletrônica    303
# dtype: int64

# %%
soma_pontuacoes.plot(kind='barh')
# Out:
# <Axes: >

# %%
df_music_mean = df_music.mean()
df_music_mean.plot(kind='barh')
plt.title('Média das Avaliações por Estilo Musical')
plt.ylabel('Média')
# Out:
# Text(0, 0.5, 'Média')

# %%
df_music.boxplot()
plt.title('Distribuição das Avaliações por Estilo Musical')
plt.xticks(rotation=90)
plt.ylabel('Avaliação')
# Out:
# Text(0, 0.5, 'Avaliação')

# %% [markdown]
# ### Tarefa 5- faça um boxplot e um histograma identique a mediana , outliers e conte uma história.

# %%
pesquisa_musical.columns=['data/hora','Rock','HipHop','MPB','Reggae','Funk','Sertanejo','Gospel','Eletronica']
pesquisa_musical
# Out:
#               data/hora  Rock  HipHop  MPB  Reggae  Funk  Sertanejo  Gospel  \
# 0   21/08/2024 10:03:25     3       1    1       1     1          1       1
# 1   21/08/2024 10:04:39     5       3    5       2     1          3       1
# 2   21/08/2024 10:04:52     1       5    1       1     1          1       1
# 3   21/08/2024 10:04:53     1       5    4       4     4          1       1
# 4   21/08/2024 10:04:55     5       4    3       4     1          1       2
# 5   21/08/2024 10:05:26     5       2    2       2     1          1       2
# 6   21/08/2024 10:05:41     2       4    4       1     4          4       1
# 7   21/08/2024 10:06:14     5       3    3       3     1          2       3
# 8   21/08/2024 10:07:16     4       4    4       1     4          4       1
# 9   21/08/2024 10:07:26     5       5    1       3     4          1       1
# 10  21/08/2024 10:07:31     3       2    5       4     3          4       4
# 11  21/08/2024 10:08:37     4       1    5       1     1          2       5
# 12  21/08/2024 10:38:46     5       1    3       1     1          1       1
# 13  21/08/2024 10:58:52     5       5    1       1     1          1       1
# 14  21/08/2024 14:58:43     5       4    4       3     3          3       2
# 15  21/08/2024 14:59:12     4       5    3       4     1          2       4
# 16  21/08/2024 14:59:39     5       4    1       2     4          1       1
# 17  21/08/2024 14:59:58     1       2    3       1     2          3       4
# 18  21/08/2024 15:00:08     4       2    4       3     1          2       3
# 19  21/08/2024 15:00:16     1       5    4       4     5          3       3
# 20  21/08/2024 15:00:27     3       5    1       1     1          1       1
# 21  21/08/2024 15:00:38     4       1    4       1     1          3       5
# 22  21/08/2024 15:01:03     4       1    4       1     1          2       1
# 23  21/08/2024 15:01:09     3       3    4       3     2          3       2
# 24  21/08/2024 15:01:36     3       3    4       3     1          1       5
# 25  21/08/2024 15:01:55     5       4    5       1     1          3       2
# 26  21/08/2024 15:02:10     3       3    4       3     1          1       5
# 27  21/08/2024 15:02:13     5       5    4       5     2          2       4
# 28  21/08/2024 15:02:16     5       4    5       2     1          3       4
# 29  21/08/2024 15:02:18     2       1    3       1     2          5       3
# 30  21/08/2024 15:03:08     5       5    5       5     5          5       5
# 31  21/08/2024 15:03:40     5       5    5       5     5          5       5
# 32  21/08/2024 15:05:02     4       1    4       1     1          3       5
# 33  21/08/2024 15:05:13     3       1    4       2     1          4       4
# 34  21/08/2024 15:06:35     5       5    2       5     1          3       4
# 35  21/08/2024 15:06:40     3       1    5       1     2          5       1
# 36  21/08/2024 15:09:30     1       4    3       2     1          3       2
# 37  21/08/2024 20:00:02     4       1    4       3     1          2       3
#
#     Eletronica
# 0            3
# 1            5
# 2            5
# 3            5
# 4            5
# 5            4
# 6            3
# 7            4
# 8            4
# 9            3
# 10           2
# 11           1
# 12           4
# 13           4
# 14           5
# 15           5
# 16           4
# 17           4
# 18           3
# 19           5
# 20           1
# 21           1
# 22           1
# 23           3
# 24           5
# 25           1
# 26           5
# 27           5
# 28           4
# 29           1
# 30           5
# 31           5
# 32           1
# 33           1
# 34           1
# 35           2
# 36           2
# 37           3
