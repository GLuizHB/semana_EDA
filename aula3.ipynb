# %% [markdown]
# # Music IA Education

# %% [markdown]
# ## Coleta de Dados

# %% [markdown]
# - Questionário via Google Forms.
# - Perguntas sobre a faixa etária, professor e estiço musical.

# %% [markdown]
# # Objetivo do Experimento
#
# - Criar músicas com ritmos e estilos músicais adequados para um turma especifica.
# - As músicas tem objetivo de auxiliar o professor com recurso didático, sendo que as letras das canções abordarão o conteudo ministrado pelo professor.
# - As músicas serão geradas por IA no software SUNO e disponibilizado em forma de link.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/pesquisa_musical.csv')
df
# Out:
#     Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0    21/08/2024 10:03:25                                  3
# 1    21/08/2024 10:04:39                                  5
# 2    21/08/2024 10:04:52                                  1
# 3    21/08/2024 10:04:53                                  1
# 4    21/08/2024 10:04:55                                  5
# ..                   ...                                ...
# 145  22/08/2024 16:52:02                                  4
# 146  22/08/2024 17:00:29                                  4
# 147  22/08/2024 17:21:09                                  3
# 148  22/08/2024 17:35:57                                  1
# 149  22/08/2024 18:59:08                                  2
#
#      Avalie os estilos musicais [rap]  Avalie os estilos musicais [mpb]  \
# 0                                   1                                 1
# 1                                   3                                 5
# ...

# %%
df.columns = ['data/hora','rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletronica','professor','faixa_etaria','samba','forro','trap','palavras']

# %%
df.head()
# Out:
#              data/hora  rock  hiphop  mpb  reggae  funk  sertanejo  gospel  \
# 0  21/08/2024 10:03:25     3       1    1       1     1          1       1
# 1  21/08/2024 10:04:39     5       3    5       2     1          3       1
# 2  21/08/2024 10:04:52     1       5    1       1     1          1       1
# 3  21/08/2024 10:04:53     1       5    4       4     4          1       1
# 4  21/08/2024 10:04:55     5       4    3       4     1          1       2
#
#    eletronica professor faixa_etaria  samba  forro  trap palavras
# 0           3       NaN          NaN    NaN    NaN   NaN      NaN
# 1           5       NaN          NaN    NaN    NaN   NaN      NaN
# 2           5       NaN          NaN    NaN    NaN   NaN      NaN
# 3           5       NaN          NaN    NaN    NaN   NaN      NaN
# 4           5       NaN          NaN    NaN    NaN   NaN      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datahora      95 non-null     object
#  1   rock          95 non-null     int64
#  2   hiphop        95 non-null     int64
#  3   mpb           95 non-null     int64
#  4   reggae        95 non-null     int64
#  5   funk          95 non-null     int64
#  6   sertanejo     95 non-null     int64
#  7   gospel        95 non-null     int64
#  8   eletrônica    95 non-null     int64
#  9   professor     57 non-null     object
#  10  faixa_etaria  57 non-null     object
# dtypes: int64(8), object(3)
# memory usage: 8.3+ KB

# %%
df.describe()
# Out:
#             rock     hiphop        mpb     reggae       funk  sertanejo  \
# count  95.000000  95.000000  95.000000  95.000000  95.000000  95.000000
# mean    3.263158   3.084211   3.242105   2.578947   2.431579   2.884211
# std     1.545140   1.534450   1.396925   1.411043   1.492197   1.457652
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     2.000000   1.500000   2.000000   1.000000   1.000000   1.500000
# 50%     4.000000   3.000000   4.000000   2.000000   2.000000   3.000000
# 75%     5.000000   4.500000   4.000000   3.500000   4.000000   4.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#           gospel  eletrônica
# count  95.000000   95.000000
# mean    2.652632    3.189474
# std     1.493022    1.573009
# min     1.000000    1.000000
# 25%     1.000000    1.000000
# 50%     2.000000    4.000000
# 75%     4.000000    5.000000
# max     5.000000    5.000000

# %% [markdown]
# 23/08
#
# - Visualizar os estilos por professor
# - Criar graficos pizza
# - Criar Gráficos de barra colorid0, com rotulos (figura)
# - Storytelling
# - Brincadeira dos 7 erros (com brinde brinde)
# - Gráfico de linha

# %%
colunas = ['rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletronica']
condicao = df['professor'] == 'Karython'
df_filtrado = df[condicao]

# %%
soma = df_filtrado[colunas].mean()

# %%
soma.plot(kind='barh', colormap='plasma', title='Pesquisa musical Karyton')
# Out:
# <Axes: title={'center': 'Pesquisa musical Karyton'}>
